# %%
import requests

# %%
api = "https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByPin"

# %%
test = requests.get(api, headers={"Accept-Language": "hi-IN"}, params={"pincode": "110059", "date": "31-01-2022"})

# %%
test
# Out:
# <Response [200]>

# %%
hospital_json = test.json()
hospital_json
# Out:
# {'sessions': [{'center_id': 651401,
#    'name': 'Aakash BM GUPTA HOSPITAL PVT.',
#    'address': '9 TO H15 UTTAM NAGAR NEW DELHI 110059',
#    'state_name': 'Delhi',
#    'district_name': 'South West Delhi',
#    'block_name': 'Not Applicable',
#    'pincode': 110059,
#    'from': '09:00:00',
#    'to': '18:00:00',
#    'lat': 28,
#    'long': 74,
#    'fee_type': 'Paid',
#    'session_id': 'f8fd3079-5d8b-403e-9e6a-cae177349d0b',
#    'date': '31-01-2022',
#    'available_capacity': 1196,
#    'available_capacity_dose1': 399,
#    'available_capacity_dose2': 399,
#    'fee': '1410',
#    'min_age_limit': 15,
#    'allow_all_age': True,
#    'vaccine': 'COVAXIN',
#    'slots': ['09:00AM-11:00AM',
#     '11:00AM-01:00PM',
#     '01:00PM-03:00PM',
#     '03:00PM-06:00PM']},
#   {'center_id': 651401,
#    'name': 'Aakash BM GUPTA HOSPITAL PVT.',
#    'address': '9 TO H15 UTTAM NAGAR NEW DELHI 110059',
#    'state_name': 'Delhi',
#    'district_name': 'South West Delhi',
# ...

# %%
for i in hospital_json:
#     print(hospital_json[i])
    for hospitals in hospital_json[i]:
#         if hospitals['name'] == "Aakash BM GUPTA HOSPITAL PVT.":
        print("{0} has {1}".format(hospitals['name'],hospitals['available_capacity']))
# Out:
# Aakash BM GUPTA HOSPITAL PVT. has 1196
# Aakash BM GUPTA HOSPITAL PVT. has 1199
# JANAKPURI C4B has 0
# PGH Hospital-1 has 519
# Mata Chanan Devi Hospital 1 has 60
# PGH Hospital-1 has 130
# Hindustan Wellness MMH has 150
# Dr Grover Children Clinic has 230
# ESI Maya Puri Phase II PHC has 100

# %%
import pandas as pd

# %%
val2 = hospital_json['sessions']
print(pd.DataFrame(val2, columns=["name", "available_capacity", "available_capacity_dose1", "available_capacity_dose2"]))
# Out:
#                             name  available_capacity  \
# 0  Aakash BM GUPTA HOSPITAL PVT.                1196
# 1  Aakash BM GUPTA HOSPITAL PVT.                1199
# 2                  JANAKPURI C4B                   0
# 3                 PGH Hospital-1                 519
# 4    Mata Chanan Devi Hospital 1                  60
# 5                 PGH Hospital-1                 130
# 6         Hindustan Wellness MMH                 150
# 7      Dr Grover Children Clinic                 230
# 8     ESI Maya Puri Phase II PHC                 100
#
#    available_capacity_dose1  available_capacity_dose2
# 0                       399                       399
# 1                       400                       399
# 2                         0                         0
# 3                       350                        49
# 4                        20                        20
# 5                        50                        50
# ...

# %%
def minChanges(a, k):
    # Write your code here
    unique = set(a)
    if k > len(unique):
        return k-len(unique)
    else:
        return 0

def main():

    n = int(input())

    k = int(input())
    a=[None]*n
    for j in range(n):
        a[j] = int(input())
    
    result = minChanges(a, k);
    print(result)
if __name__ == "__main__":
    main()
# Out:
# 4
# 3
# 4
# 5
# 5
# 5
# 1

# %%
# Python 3 program to minimum changes required
# in an array for k distinct elements.
MAX = 100005

# Function to minimum changes required
# in an array for k distinct elements.
def minChanges(arr, n, k):
	arr.sort(reverse = False)

	# Store the frequency of each element
	freq = [0 for i in range(MAX)]
	
	p = 0
	freq[p] = 1
	
	# Store the frequency of elements
	for i in range(1, n, 1):
		if (arr[i] == arr[i - 1]):
			freq[p] += 1
		else:
			p += 1
			freq[p] += 1

	# Sort frequencies in descending order
	freq.sort(reverse = True)
	
	# To store the required answer
	ans = 0
	for i in range(k, p + 1, 1):
		ans += freq[i]
		
	# Return the required answer
	return ans

# Driver code
if __name__ == '__main__':
    n = int(input())

    k = int(input())
    a=[None]*n
    for j in range(n):
        a[j] = int(input())
    
    result = minChanges(arr, n, k);
    print(result)
# Out:
# 4
# 3
# 4
# 5
# 5
# 5
# 0

# %% [markdown]
# import sys
#
#
# def countWays(n, k):
#     # Write your code here
#
#
#
# def main():
#     n = int(sys.stdin.readline().strip())
#
#     k = int(sys.stdin.readline().strip())
#
#     result = countWays(n, k)
#
#     print(result)
#
#
# if __name__ == "__main__":
#     main()

# %%
import sys


def countWays(n, k):
    # Write your code here
    pass


def main():
    n = int(sys.stdin.readline().strip())
    
    k = int(sys.stdin.readline().strip())

    result = countWays(n, k)

    print(result)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-54b4651234d7> in <module>
#      18
#      19 if __name__ == "__main__":
# ---> 20     main()
#
# <ipython-input-59-54b4651234d7> in main()
#       8
#       9 def main():
# ---> 10     n = int(sys.stdin.readline().strip())
#      11
#      12     k = int(sys.stdin.readline().strip())
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a = "asdfghjkl"
rev = ""
for i in a:
    rev = i+rev
print(rev)
# Out:
# lkjhgfdsa
